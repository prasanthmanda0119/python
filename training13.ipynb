# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.sample(10) #no of rows for a sample
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 421         0       3    male  21.0      0      0    7.7333        Q   Third
# 347         1       3  female   NaN      1      0   16.1000        S   Third
# 41          0       2  female  27.0      1      0   21.0000        S  Second
# 547         1       2    male   NaN      0      0   13.8625        C  Second
# 768         0       3    male   NaN      1      0   24.1500        Q   Third
# 549         1       2    male   8.0      1      1   36.7500        S  Second
# 518         1       2  female  36.0      1      0   26.0000        S  Second
# 160         0       3    male  44.0      0      1   16.1000        S   Third
# 514         0       3    male  24.0      0      0    7.4958        S   Third
# 118         0       1    male  24.0      0      1  247.5208        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 421    man        True  NaN   Queenstown    no   True
# ...

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 396         0       3  female  31.0      0      0   7.8542        S  Third
# 35          0       1    male  42.0      1      0  52.0000        S  First
# 283         1       3    male  19.0      0      0   8.0500        S  Third
# 448         1       3  female   5.0      2      1  19.2583        C  Third
# 94          0       3    male  59.0      0      0   7.2500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 396  woman       False  NaN  Southampton    no   True
# 35     man        True  NaN  Southampton    no  False
# 283    man        True  NaN  Southampton   yes   True
# 448  child       False  NaN    Cherbourg   yes  False
# 94     man        True  NaN  Southampton    no   True

# %%
df.head(10)#strating rows
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df.tail(10)#ending rows
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 881    man        True  NaN  Southampton    no   True
# ...

# %%
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df['age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
df['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].isnull().sum()
# Out:
# 177

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#percentage of missing ages
(177/891)*100
# Out:
# 19.865319865319865

# %%
(df.isnull().sum()/891)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive  alone
# ...

# %%
df.drop('embark_town',axis=1)#used to delete the column
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck alive  alone
# ...

# %%
df.drop('embark_town', axis=1, inplace=True)#to ensure that it is deleted

# %%
df.drop(['class','who'], axis=1)
# Out:
#      survived  pclass  sibsp  parch embarked  adult_male deck alive  alone
# 0           0       3      1      0        S        True  NaN    no  False
# 1           1       1      1      0        C       False    C   yes  False
# 2           1       3      0      0        S       False  NaN   yes   True
# 3           1       1      1      0        S       False    C   yes  False
# 4           0       3      0      0        S        True  NaN    no   True
# ..        ...     ...    ...    ...      ...         ...  ...   ...    ...
# 886         0       2      0      0        S        True  NaN    no   True
# 887         1       1      0      0        S       False    B   yes   True
# 888         0       3      1      2        S       False  NaN    no  False
# 889         1       1      0      0        C        True    C   yes   True
# 890         0       3      0      0        Q        True  NaN    no   True
#
# [891 rows x 9 columns]

# %%
df.drop(['class','who'], axis=1, inplace=True)#axis=1 is used to delete the rows

# %%
df
# Out:
#      survived  pclass  sibsp  parch embarked  adult_male deck alive  alone
# 0           0       3      1      0        S        True  NaN    no  False
# 1           1       1      1      0        C       False    C   yes  False
# 2           1       3      0      0        S       False  NaN   yes   True
# 3           1       1      1      0        S       False    C   yes  False
# 4           0       3      0      0        S        True  NaN    no   True
# ..        ...     ...    ...    ...      ...         ...  ...   ...    ...
# 886         0       2      0      0        S        True  NaN    no   True
# 887         1       1      0      0        S       False    B   yes   True
# 888         0       3      1      2        S       False  NaN    no  False
# 889         1       1      0      0        C        True    C   yes   True
# 890         0       3      0      0        Q        True  NaN    no   True
#
# [891 rows x 9 columns]

# %%
df.drop([1,888,887,890],axis=0) #axis=0 is used to delete the column by providing the indexes of columns to be deleted
# Out:
#      survived  pclass  sibsp  parch embarked  adult_male deck alive  alone
# 0           0       3      1      0        S        True  NaN    no  False
# 2           1       3      0      0        S       False  NaN   yes   True
# 3           1       1      1      0        S       False    C   yes  False
# 4           0       3      0      0        S        True  NaN    no   True
# 5           0       3      0      0        Q        True  NaN    no   True
# ..        ...     ...    ...    ...      ...         ...  ...   ...    ...
# 883         0       2      0      0        S        True  NaN    no   True
# 884         0       3      0      0        S        True  NaN    no   True
# 885         0       3      0      5        Q       False  NaN    no  False
# 886         0       2      0      0        S        True  NaN    no   True
# 889         1       1      0      0        C        True    C   yes   True
#
# [887 rows x 9 columns]

# %%
df.drop([1,888,887,890],axis=0, inplace=True)
